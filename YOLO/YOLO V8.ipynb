# %%
# !nvidia-smi
# Out:
# Mon Jun  5 14:51:08 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8    12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.5/593.5 kB 36.9 MB/s eta 0:00:00
# ...

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/zidane.jpg'
# here source can be changed to desired path location in jupyter nb
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 341MB/s]
# Ultralytics YOLOv8.0.113 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# ...
# 100% 165k/165k [00:00<00:00, 51.3MB/s]
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 65.2ms
# Speed: 10.8ms preprocess, 65.2ms inference, 36.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source='/content/drive/MyDrive/YOLO/Images/2C3D.jpg'
# Out:
# Ultralytics YOLOv8.0.113 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/YOLO/Images/2C3D.jpg: 320x640 4 cats, 4 dogs, 146.0ms
# Speed: 22.4ms preprocess, 146.0ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %% [markdown]
# SEGMENTATION

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt source='/content/drive/MyDrive/YOLO/Images/2C3D.jpg'
# Out:
# ...
# 100% 6.73M/6.73M [00:00<00:00, 344MB/s]
# Ultralytics YOLOv8.0.113 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/YOLO/Images/2C3D.jpg: 320x640 2 cats, 3 dogs, 86.3ms
# Speed: 2.5ms preprocess, 86.3ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict

# %% [markdown]
# Python Script

# %%
from ultralytics import YOLO

# %%
# Loading the model
model=YOLO("/yolov8n-seg.pt")
model.predict(source='/content/drive/MyDrive/YOLO/Images/2C3D.jpg')
# Out:
# ...
# 100%|██████████| 6.73M/6.73M [00:00<00:00, 327MB/s]
#
# image 1/1 /content/drive/MyDrive/YOLO/Images/2C3D.jpg: 320x640 2 cats, 3 dogs, 90.5ms
# Speed: 2.7ms preprocess, 90.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes', 'masks']
#  masks: ultralytics.yolo.engine.results.Masks object
# ...

# %% [markdown]
# CLASSIFICATION

# %%
# !yolo task=classify mode=predict model=yolov8n-cls.pt source='/content/drive/MyDrive/YOLO/Images/2C3D.jpg'
# Out:
# ...
# 100% 5.28M/5.28M [00:00<00:00, 238MB/s]
# Ultralytics YOLOv8.0.113 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2715880 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/YOLO/Images/2C3D.jpg: 224x224 basset 0.24, Welsh_springer_spaniel 0.18, English_foxhound 0.12, beagle 0.09, Walker_hound 0.06, 2.6ms
# Speed: 17.7ms preprocess, 2.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict

# %% [markdown]
# YOLO on Custom Data Set

# %%
import os
HOME=os.getcwd()
